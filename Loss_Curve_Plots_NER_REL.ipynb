
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_ner, color='dodgerblue',label='Loss NER (CPU)')
plt.title('Loss Curve Plot for NER using tok2vec')
plt.xlabel('Epochs')
plt.ylabel('Loss of NER (CPU)')
plt.legend()
plt.show()

# %% [markdown]
# ## 2) Loss Curve Plot for NER using GPU
# ### i) roberta-base Transformer

# %%
# loss_ner=[1425.62,157779.29,98862.78,76498.32,66122.24,57993.70,51990.41,47476.93,42464.93,40835.80,37280.94,35086.13]
# epochs=[0,2,4,7,9,12,14,17,19,22,24,27]
# plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_ner, color='indigo',label='Loss NER (GPU)')
# plt.title('Loss Curve Plot for NER using roberta-base transformer')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
loss_ner=[157779.29,98862.78,76498.32,66122.24,57993.70,51990.41,47476.93,42464.93,40835.80,37280.94,35086.13]
epochs=[2,4,7,9,12,14,17,19,22,24,27]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_ner, color='indigo',label='Loss NER (GPU)')
plt.title('Loss Curve Plot for NER using roberta-base transformer')
plt.xlabel('Epochs')
plt.ylabel('Loss of NER using roberta-base transformer (GPU) ')
plt.legend()
plt.show()

# %%
loss_ner=[66122.24,57993.70,51990.41,47476.93,42464.93,40835.80,37280.94,35086.13]
epochs=[9,12,14,17,19,22,24,27]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_ner, color='indigo',label='Loss NER (GPU)')
plt.title('Loss Curve Plot for NER using roberta-base transformer')
plt.xlabel('Epochs')
plt.ylabel('Loss of NER using roberta-base transformer (GPU) ')
plt.legend()
plt.show()

# %% [markdown]
# ### ii) bert-base-uncased Transformer

# %%
# loss_ner=[1501.17,156494.59,94461.72,73759.34,61554.79,51732.15,45739.12,
#           41759.88,38016.38,36360.94,33436.99,32044.70]
# epochs=[0,2,4,7,9,12,14,17,19,22,24,27]
# plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_ner,color='magenta', label='Loss NER (GPU)')
# plt.title('Loss Curve Plot for NER using bert-base-uncased transformer')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
loss_ner=[156494.59,94461.72,73759.34,61554.79,51732.15,45739.12,
          41759.88,38016.38,36360.94,33436.99,32044.70]
epochs=[2,4,7,9,12,14,17,19,22,24,27]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_ner,color='magenta', label='Loss NER (GPU)')
plt.title('Loss Curve Plot for NER using bert-base-uncased transformer')
plt.xlabel('Epochs')
plt.ylabel('Loss of NER using bert-base-uncased transformer (GPU)')
plt.legend()
plt.show()

# %%
loss_ner=[61554.79,51732.15,45739.12,
          41759.88,38016.38,36360.94,33436.99,32044.70]
epochs=[9,12,14,17,19,22,24,27]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_ner,color='magenta', label='Loss NER (GPU)')
plt.title('Loss Curve Plot for NER using bert-base-uncased transformer')
plt.xlabel('Epochs')
plt.ylabel('Loss of NER using bert-base-uncased transformer (GPU)')
plt.legend()
plt.show()

# %% [markdown]
# ### iii) bionlp bluebert Transformer

# %%
# loss_ner=[1716.80,164342.45,95817.50,74910.30,62661.02,52801.44,46893.40,
#           43121.46,38897.22,36880.37,33898.17,32203.12,30801.34,29330.86,
#           28340.35,26722.10,24261.42,23351.57,21310.38,19330.18,17222.72,14439.80,
#           12186.05,9879.91,7386.73,5587.58,4088.47,2854.08,2011.26,1429.54,1156.61,
#           905.97,749.94,545.14,610.28]
# epochs=[0,2,4,7,9,12,14,17,19,22,24,27,
#         29,32,34,37,39,41,44,46,49,51,54,56,59,
#         61,64,66,69,71,74,76,78,81,83]
# plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_ner, color='lime',label='Loss NER (GPU)')
# plt.title('Loss Curve Plot for NER using bionlp bluebert transformer')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
loss_ner=[164342.45,95817.50,74910.30,62661.02,52801.44,46893.40,
          43121.46,38897.22,36880.37,33898.17,32203.12,30801.34,29330.86,
          28340.35,26722.10,24261.42,23351.57,21310.38,19330.18,17222.72,14439.80,
          12186.05,9879.91,7386.73,5587.58,4088.47,2854.08,2011.26,1429.54,1156.61,
          905.97,749.94,545.14,610.28]
epochs=[2,4,7,9,12,14,17,19,22,24,27,
        29,32,34,37,39,41,44,46,49,51,54,56,59,
        61,64,66,69,71,74,76,78,81,83]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_ner, color='lime',label='Loss NER (GPU)')
plt.title('Loss Curve Plot for NER using bionlp bluebert transformer')
plt.xlabel('Epochs')
plt.ylabel('Loss of NER using bionlp bluebert transformer (GPU)')
plt.legend()
plt.show()

# %%
loss_ner=[74910.30,62661.02,52801.44,46893.40,
          43121.46,38897.22,36880.37,33898.17,32203.12,30801.34,29330.86,
          28340.35,26722.10,24261.42,23351.57,21310.38,19330.18,17222.72,14439.80,
          12186.05,9879.91,7386.73,5587.58,4088.47,2854.08,2011.26,1429.54,1156.61,
          905.97,749.94,545.14,610.28]
epochs=[7,9,12,14,17,19,22,24,27,
        29,32,34,37,39,41,44,46,49,51,54,56,59,
        61,64,66,69,71,74,76,78,81,83]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_ner, color='lime',label='Loss NER (GPU)')
plt.title('Loss Curve Plot for NER using bionlp bluebert transformer')
plt.xlabel('Epochs')
plt.ylabel('Loss of NER using bionlp bluebert transformer (GPU)')
plt.legend()
plt.show()

# %% [markdown]
# # 3) Loss Curve Plot for REL using CPU  and GPU
# ### 3.1) Tok2vec

# %%
# loss_rel=[0.44,42.92,7.89,5.55,4.72,3.74,3.53,3.65,4.05,
#           4.55,4.19,4.24,4.13,4.16,4.09,3.49,3.40,3.66,3.46,3.50,3.59]
# epochs=[0,17,47,97,180,302,427,552,677,802,927,1052,1177,1302,1427,1552,1677,1802,1927,2052,2177]
# plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_rel,color='red', label='Loss REL (CPU)')
# plt.title('Loss Curve Plot for REL using tok2vec')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
loss_rel=[42.92,7.89,5.55,4.72,3.74,3.53,3.65,4.05,
          4.55,4.19,4.24,4.13,4.16,4.09,3.49,3.40,3.66,3.46,3.50,3.59]
epochs=[17,47,97,180,302,427,552,677,802,927,1052,1177,1302,1427,1552,1677,1802,1927,2052,2177]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel,color='red', label='Loss REL (CPU)')
plt.title('Loss Curve Plot for REL using tok2vec')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using tok2vec')
plt.legend()
plt.show()

# %%
loss_rel=[7.89,5.55,4.72,3.74,3.53,3.65,4.05,
          4.55,4.19,4.24,4.13,4.16,4.09,3.49,3.40,3.66,3.46,3.50,3.59]
epochs=[47,97,180,302,427,552,677,802,927,1052,1177,1302,1427,1552,1677,1802,1927,2052,2177]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel,color='red', label='Loss REL (CPU)')
plt.title('Loss Curve Plot for REL using tok2vec')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using tok2vec')
plt.legend()
plt.show()

# %% [markdown]
# ### 3.2) Transformers
# #### i) bert-base uncased Transformer (CPU)

# %%
# loss_rel=[0.44,42.54,7.78,6.02,4.54,3.57,3.40,3.63,4.42,
#           3.54,3.52,3.69,3.52,4.14,3.60,3.47,3.43,3.66,3.46,3.50,3.59]
# epochs=[0,17,47,97,180,302,427,552,677,802,927,1052,1177,1302,1427,1552,1677,1802,1927,2052,2177]
# plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_rel, color='yellow', label='Loss REL (CPU)')
# plt.title('Loss Curve Plot for REL using bert-base uncased transformer in CPU')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
loss_rel=[42.54,7.78,6.02,4.54,3.57,3.40,3.63,4.42,
          3.54,3.52,3.69,3.52,4.14,3.60,3.47,3.43,3.66,3.46,3.50,3.59]
epochs=[17,47,97,180,302,427,552,677,802,927,1052,1177,1302,1427,1552,1677,1802,1927,2052,2177]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel, color='yellow', label='Loss REL (CPU)')
plt.title('Loss Curve Plot for REL using bert-base uncased transformer in CPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using bert-base uncased transformer (CPU) ')
plt.legend()
plt.show()

# %%
loss_rel=[7.78,6.02,4.54,3.57,3.40,3.63,4.42,
          3.54,3.52,3.69,3.52,4.14,3.60,3.47,3.43,3.66,3.46,3.50,3.59]
epochs=[47,97,180,302,427,552,677,802,927,1052,1177,1302,1427,1552,1677,1802,1927,2052,2177]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel, color='yellow', label='Loss REL (CPU)')
plt.title('Loss Curve Plot for REL using bert-base uncased transformer in CPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using bert-base uncased transformer (CPU) ')
plt.legend()
plt.show()

# %% [markdown]
# #### ii) bert-base uncased Transformer (GPU)

# %%
# loss_rel=[0.47,13.92,0.73,0.32,0.30,0.29,0.28,0.37,0.29,0.27,0.28]
# epochs=[0,33,66,100,133,166,200,233,266,300,333]
# plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_rel, color='olive',label='Loss REL (GPU)')
# plt.title('Loss Curve Plot for REL using bert-base uncased transformer in GPU')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
loss_rel=[13.92,0.73,0.32,0.30,0.29,0.28,0.37,0.29,0.27,0.28]
epochs=[33,66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel, color='olive',label='Loss REL (GPU)')
plt.title('Loss Curve Plot for REL using bert-base uncased transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using bert-base uncased transformer (GPU)')
plt.legend()
plt.show()

# %%
loss_rel=[0.73,0.32,0.30,0.29,0.28,0.37,0.29,0.27,0.28]
epochs=[66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel, color='olive',label='Loss REL (GPU)')
plt.title('Loss Curve Plot for REL using bert-base uncased transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using bert-base uncased transformer (GPU)')
plt.legend()
plt.show()

# %% [markdown]
# #### iii) bionlp bluebert Transformer (CPU)

# %%
# loss_rel=[0.44,42.54,7.78,6.02,4.54,3.57,3.40,3.63,4.42,
#           3.54,3.52,3.69,3.52,4.14,3.60,3.47,3.43,3.66,3.46,3.50,3.59]
# epochs=[0,17,47,97,180,302,427,552,677,802,927,1052,1177,1302,1427,1552,1677,1802,1927,2052,2177]
# plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_rel, color='cyan',label='Loss REL (CPU)')
# plt.title('Loss Curve Plot for REL using bionlp bluebert transformer in CPU')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
loss_rel=[42.54,7.78,6.02,4.54,3.57,3.40,3.63,4.42,
          3.54,3.52,3.69,3.52,4.14,3.60,3.47,3.43,3.66,3.46,3.50,3.59]
epochs=[17,47,97,180,302,427,552,677,802,927,1052,1177,1302,1427,1552,1677,1802,1927,2052,2177]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel, color='cyan',label='Loss REL (CPU)')
plt.title('Loss Curve Plot for REL using bionlp bluebert transformer in CPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using bionlp bluebert transformer (CPU) ')
plt.legend()
plt.show()

# %%
loss_rel=[7.78,6.02,4.54,3.57,3.40,3.63,4.42,
          3.54,3.52,3.69,3.52,4.14,3.60,3.47,3.43,3.66,3.46,3.50,3.59]
epochs=[47,97,180,302,427,552,677,802,927,1052,1177,1302,1427,1552,1677,1802,1927,2052,2177]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel, color='cyan',label='Loss REL (CPU)')
plt.title('Loss Curve Plot for REL using bionlp bluebert transformer in CPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using bionlp bluebert transformer (CPU) ')
plt.legend()
plt.show()

# %% [markdown]
# #### iv) bionlp bluebert Transformer (GPU)

# %%
# loss_rel=[0.45,15.67,0.89,0.35,0.31,0.30,0.28,0.32,0.28,0.27,0.28]
# epochs=[0,33,66,100,133,166,200,233,266,300,333]
# plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_rel,color='brown', label='Loss REL (GPU)')
# plt.title('Loss Curve Plot for REL using bionlp bluebert transformer in GPU')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
loss_rel=[15.67,0.89,0.35,0.31,0.30,0.28,0.32,0.28,0.27,0.28]
epochs=[33,66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel,color='brown', label='Loss REL (GPU)')
plt.title('Loss Curve Plot for REL using bionlp bluebert transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using bionlp bluebert transformer (GPU) ')
plt.legend()
plt.show()

# %%
loss_rel=[0.89,0.35,0.31,0.30,0.28,0.32,0.28,0.27,0.28]
epochs=[66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel,color='brown', label='Loss REL (GPU)')
plt.title('Loss Curve Plot for REL using bionlp bluebert transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using bionlp bluebert transformer (GPU) ')
plt.legend()
plt.show()

# %% [markdown]
# #### v) roberta-base Transformer (CPU)

# %%
# loss_rel=[0.44,42.54,7.78,6.02,4.54,3.57,3.40,3.63,4.42,
#           3.54,3.52,3.69,3.52,4.14,3.60,3.47,3.43,3.66,3.46,3.50,3.59]
# epochs=[0,17,47,97,180,302,427,552,677,802,927,1052,1177,1302,1427,1552,1677,1802,1927,2052,2177]
# plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_rel, color='red',label='Loss REL (CPU)')
# plt.title('Loss Curve Plot for REL using roberta-base transformer in CPU')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
loss_rel=[42.54,7.78,6.02,4.54,3.57,3.40,3.63,4.42,
          3.54,3.52,3.69,3.52,4.14,3.60,3.47,3.43,3.66,3.46,3.50,3.59]
epochs=[17,47,97,180,302,427,552,677,802,927,1052,1177,1302,1427,1552,1677,1802,1927,2052,2177]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel, color='red',label='Loss REL (CPU)')
plt.title('Loss Curve Plot for REL using roberta-base transformer in CPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using roberta-base transformer (CPU) ')
plt.legend()
plt.show()

# %%
loss_rel=[3.47,3.43,3.66,3.46,3.50,3.59]
epochs=[1552,1677,1802,1927,2052,2177]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel, color='red',label='Loss REL (CPU)')
plt.title('Loss Curve Plot for REL using roberta-base transformer in CPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using roberta-base transformer (CPU) ')
plt.legend()
plt.show()

# %% [markdown]
# #### vi) roberta-base transformer (GPU)

# %%
# loss_rel=[0.74,20.40,0.89,0.44,0.33,0.29,0.28,0.28,0.28,0.27,0.28]
# epochs=[0,33,66,100,133,166,200,233,266,300,333]
# plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_rel,color='orange', label='Loss REL (GPU)')
# plt.title('Loss Curve Plot for REL using roberta-base transformer in GPU')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
loss_rel=[20.40,0.89,0.44,0.33,0.29,0.28,0.28,0.28,0.27,0.28]
epochs=[33,66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel,color='orange', label='Loss REL (GPU)')
plt.title('Loss Curve Plot for REL using roberta-base transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using roberta-base transformer (GPU) ')
plt.legend()
plt.show()

# %%
loss_rel=[0.89,0.44,0.33,0.29,0.28,0.28,0.28,0.27,0.28]
epochs=[66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel,color='orange', label='Loss REL (GPU)')
plt.title('Loss Curve Plot for REL using roberta-base transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using roberta-base transformer (GPU) ')
plt.legend()
plt.show()

# %% [markdown]
# # 4) Loss Curve Plot for Combined pipeline (NER + REL) using GPU
# ## 4.1) Transformer
# ### i) roberta-base Transformer

# %%
# loss_ner=[358.60,52179.01,182.73,79.86,77.57,56.23,69.96,68.53,55.38,52.87,54.26]
# # loss_rel=[0.61,32.72,9.82,2.58,1.17,0.31,0.28,0.22,0.23,0.21,0.21]
# epochs=[0,33,66,100,133,166,200,233,266,300,333]
# plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_ner, color='blue', label='Loss NER (GPU)')
# # plt.plot(epochs, loss_rel, color='green',label='Loss REL (GPU)')
# plt.title('Loss Curve Plot for Combined pipeline (NER + REL) using roberta-base transformer in GPU')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
loss_ner=[52179.01,182.73,79.86,77.57,56.23,69.96,68.53,55.38,52.87,54.26]
# loss_rel=[0.61,32.72,9.82,2.58,1.17,0.31,0.28,0.22,0.23,0.21,0.21]
epochs=[33,66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_ner, color='blue', label='Loss NER (GPU)')
# plt.plot(epochs, loss_rel, color='green',label='Loss REL (GPU)')
plt.title('Loss Curve Plot for Combined pipeline (NER + REL) using roberta-base transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of NER using roberta-base transformer (GPU) ')
plt.legend()
plt.show()

# %%
loss_ner=[182.73,79.86,77.57,56.23,69.96,68.53,55.38,52.87,54.26]
# loss_rel=[0.61,32.72,9.82,2.58,1.17,0.31,0.28,0.22,0.23,0.21,0.21]
epochs=[66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_ner, color='blue', label='Loss NER (GPU)')
# plt.plot(epochs, loss_rel, color='green',label='Loss REL (GPU)')
plt.title('Loss Curve Plot for Combined pipeline (NER + REL) using roberta-base transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of NER using roberta-base transformer (GPU) ')
plt.legend()
plt.show()

# %%
# # loss_ner=[358.60,52179.01,182.73,79.86,77.57,56.23,69.96,68.53,55.38,52.87,54.26]
# loss_rel=[0.61,32.72,9.82,2.58,1.17,0.31,0.28,0.22,0.23,0.21,0.21]
# epochs=[0,33,66,100,133,166,200,233,266,300,333]
# plt.figure(figsize=(10,5))
# # plt.plot(epochs, loss_ner, color='blue', label='Loss NER (GPU)')
# plt.plot(epochs, loss_rel, color='green',label='Loss REL (GPU)')
# plt.title('Loss Curve Plot for Combined pipeline (NER + REL) using roberta-base transformer in GPU')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
# loss_ner=[358.60,52179.01,182.73,79.86,77.57,56.23,69.96,68.53,55.38,52.87,54.26]
loss_rel=[32.72,9.82,2.58,1.17,0.31,0.28,0.22,0.23,0.21,0.21]
epochs=[33,66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_ner, color='blue', label='Loss NER (GPU)')
plt.plot(epochs, loss_rel, color='green',label='Loss REL (GPU)')
plt.title('Loss Curve Plot for Combined pipeline (NER + REL) using roberta-base transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using roberta-base transformer (GPU) ')
plt.legend()
plt.show()

# %%
# loss_ner=[358.60,52179.01,182.73,79.86,77.57,56.23,69.96,68.53,55.38,52.87,54.26]
loss_rel=[9.82,2.58,1.17,0.31,0.28,0.22,0.23,0.21,0.21]
epochs=[66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_ner, color='blue', label='Loss NER (GPU)')
plt.plot(epochs, loss_rel, color='green',label='Loss REL (GPU)')
plt.title('Loss Curve Plot for Combined pipeline (NER + REL) using roberta-base transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using roberta-base transformer (GPU) ')
plt.legend()
plt.show()

# %% [markdown]
# #### ii) bert-base uncased Transformer

# %%
# loss_ner=[353.06,48745.23,94.11,58.40,63.68,53.62,53.42,54.83,58.08,62.42,63.06]
# # loss_rel=[0.41,24.93,6.64,0.86,0.18,0.12,0.11,0.11,0.11,0.15,0.15]
# epochs=[0,33,66,100,133,166,200,233,266,300,333]
# plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_ner, color='gold', label='Loss NER (GPU)')
# # plt.plot(epochs, loss_rel, color='navy',label='Loss REL (GPU)')
# plt.title('Loss Curve Plot for Combined pipeline (NER + REL) using bert-base uncased transformer in GPU')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
loss_ner=[48745.23,94.11,58.40,63.68,53.62,53.42,54.83,58.08,62.42,63.06]
# loss_rel=[0.41,24.93,6.64,0.86,0.18,0.12,0.11,0.11,0.11,0.15,0.15]
epochs=[33,66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_ner, color='gold', label='Loss NER (GPU)')
# plt.plot(epochs, loss_rel, color='navy',label='Loss REL (GPU)')
plt.title('Loss Curve Plot for Combined pipeline (NER + REL) using bert-base uncased transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of NER using bert-base uncased transformer (GPU) ')
plt.legend()
plt.show()

# %%
loss_ner=[94.11,58.40,63.68,53.62,53.42,54.83,58.08,62.42,63.06]
# loss_rel=[0.41,24.93,6.64,0.86,0.18,0.12,0.11,0.11,0.11,0.15,0.15]
epochs=[66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_ner, color='gold', label='Loss NER (GPU)')
# plt.plot(epochs, loss_rel, color='navy',label='Loss REL (GPU)')
plt.title('Loss Curve Plot for Combined pipeline (NER + REL) using bert-base uncased transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of NER using bert-base uncased transformer (GPU) ')
plt.legend()
plt.show()

# %%
# # loss_ner=[353.06,48745.23,94.11,58.40,63.68,53.62,53.42,54.83,58.08,62.42,63.06]
# loss_rel=[0.41,24.93,6.64,0.86,0.18,0.12,0.11,0.11,0.11,0.15,0.15]
# epochs=[0,33,66,100,133,166,200,233,266,300,333]
# plt.figure(figsize=(10,5))
# # plt.plot(epochs, loss_ner, color='gold', label='Loss NER (GPU)')
# plt.plot(epochs, loss_rel, color='navy',label='Loss REL (GPU)')
# plt.title('Loss Curve Plot for Combined pipeline (NER + REL) using bert-base uncased transformer in GPU')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
# loss_ner=[353.06,48745.23,94.11,58.40,63.68,53.62,53.42,54.83,58.08,62.42,63.06]
loss_rel=[24.93,6.64,0.86,0.18,0.12,0.11,0.11,0.11,0.15,0.15]
epochs=[33,66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_ner, color='gold', label='Loss NER (GPU)')
plt.plot(epochs, loss_rel, color='navy',label='Loss REL (GPU)')
plt.title('Loss Curve Plot for Combined pipeline (NER + REL) using bert-base uncased transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using bert-base uncased transformer (GPU) ')
plt.legend()
plt.show()

# %%
# loss_ner=[353.06,48745.23,94.11,58.40,63.68,53.62,53.42,54.83,58.08,62.42,63.06]
loss_rel=[0.18,0.12,0.11,0.11,0.11,0.15,0.15]
epochs=[133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_ner, color='gold', label='Loss NER (GPU)')
plt.plot(epochs, loss_rel, color='navy',label='Loss REL (GPU)')
plt.title('Loss Curve Plot for Combined pipeline (NER + REL) using bert-base uncased transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using bert-base uncased transformer (GPU) ')
plt.legend()
plt.show()

# %% [markdown]
# #### iii) bionlp bluebert Transformer

# %%
# loss_ner=[356.22,57280.58,125.86,79.21,57.41,53.61,53.41,54.82,53.0,52.79,54.17]
# # loss_rel=[0.45,29.17,10.21,1.58,0.33,0.25,0.23,0.23,0.23,0.22,0.22]
# epochs=[0,33,66,100,133,166,200,233,266,300,333]
# plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_ner, color='blueviolet', label='Loss NER (GPU)')
# # plt.plot(epochs, loss_rel, color='maroon',label='Loss REL (GPU)')
# plt.title('Loss Curve Plot for Combined pipeline (NER + REL) using bionlp bluebert transformer in GPU')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
loss_ner=[57280.58,125.86,79.21,57.41,53.61,53.41,54.82,53.0,52.79,54.17]
# loss_rel=[0.45,29.17,10.21,1.58,0.33,0.25,0.23,0.23,0.23,0.22,0.22]
epochs=[33,66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_ner, color='blueviolet', label='Loss NER (GPU)')
# plt.plot(epochs, loss_rel, color='maroon',label='Loss REL (GPU)')
plt.title('Loss Curve Plot for Combined pipeline (NER + REL) using bionlp bluebert transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of NER using bionlp bluebert transformer (GPU) ')
plt.legend()
plt.show()

# %%
loss_ner=[79.21,57.41,53.61,53.41,54.82,53.0,52.79,54.17]
# loss_rel=[0.45,29.17,10.21,1.58,0.33,0.25,0.23,0.23,0.23,0.22,0.22]
epochs=[100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_ner, color='blueviolet', label='Loss NER (GPU)')
# plt.plot(epochs, loss_rel, color='maroon',label='Loss REL (GPU)')
plt.title('Loss Curve Plot for Combined pipeline (NER + REL) using bionlp bluebert transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of NER using bionlp bluebert transformer (GPU) ')
plt.legend()
plt.show()

# %%
# loss_rel=[0.45,29.17,10.21,1.58,0.33,0.25,0.23,0.23,0.23,0.22,0.22]
# epochs=[0,33,66,100,133,166,200,233,266,300,333]
# plt.figure(figsize=(10,5))
# plt.plot(epochs, loss_rel, color='maroon',label='Loss REL (GPU)')
# plt.title('Loss Curve Plot for Combined pipeline (NER+REL) using bionlp bluebert transformer in GPU')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
loss_rel=[29.17,10.21,1.58,0.33,0.25,0.23,0.23,0.23,0.22,0.22]
epochs=[33,66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel, color='maroon',label='Loss REL (GPU)')
plt.title('Loss Curve Plot for Combined pipeline (NER+REL) using bionlp bluebert transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using bionlp bluebert transformer (GPU)')
plt.legend()
plt.show()

# %%
loss_rel=[0.33,0.25,0.23,0.23,0.23,0.22,0.22]
epochs=[133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_rel, color='maroon',label='Loss REL (GPU)')
plt.title('Loss Curve Plot for Combined pipeline (NER+REL) using bionlp bluebert transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
loss_ner=[57280.58,125.86,79.21,57.41,53.61,53.41,54.82,53.0,52.79,54.17]
loss_rel=[29.17,10.21,1.58,0.33,0.25,0.23,0.23,0.23,0.22,0.22]
epochs=[33,66,100,133,166,200,233,266,300,333]
plt.figure(figsize=(10,5))
plt.plot(epochs, loss_ner, color='blueviolet', label='Loss NER (GPU)')
plt.plot(epochs, loss_rel, color='maroon',label='Loss REL (GPU)')
plt.title('Loss Curve Plot for Combined pipeline (NER+REL) using bionlp bluebert transformer in GPU')
plt.xlabel('Epochs')
plt.ylabel('Loss of REL using bionlp bluebert transformer (GPU)')
plt.legend()
plt.show()
